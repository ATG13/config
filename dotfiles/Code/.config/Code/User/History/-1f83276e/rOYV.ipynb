# %%
import pandas as pd

# %%
data = pd.read_csv('netflix_titles_clean.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   show_id            8807 non-null   object
#  1   type               8807 non-null   object
#  2   title              8807 non-null   object
#  3   director           8807 non-null   object
#  4   cast               8807 non-null   object
#  5   country            8807 non-null   object
#  6   date_added         0 non-null      float64
#  7   release_year       8807 non-null   int64
#  8   rating             8807 non-null   object
#  9   duration           8807 non-null   object
#  10  listed_in          8807 non-null   object
#  11  description        8807 non-null   object
#  12  date_missing_flag  8807 non-null   int64
#  13  year_added         0 non-null      float64
#  14  month_added        0 non-null      float64
#  15  show_age           8807 non-null   int64
# ...

# %%
cols = ["type", "country", "release_year", "rating", "duration", "listed_in"]

df = data[cols]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   country       8807 non-null   object
#  2   release_year  8807 non-null   int64
#  3   rating        8807 non-null   object
#  4   duration      8807 non-null   object
#  5   listed_in     8807 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 413.0+ KB

# %%
df.to_csv('netflix.csv', index=False)
